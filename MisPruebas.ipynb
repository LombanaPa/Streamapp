# %%
import pandas as pd

# %%
df = pd.read_csv("Ofertas_finales.csv",sep="|")
#city = pd.read_csv("vw_geografia.csv",sep=",")
# Out:
# c:\Users\ecm7985d\.conda\envs\stream\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import plotly.express as px

# %%
px.box(df.query("Canon>=100000 and Canon<=1_000_000"),x='Canon',notched=True)

# %%
df.head(3)
# Out:
#    Unnamed: 0   Longitud    Latitud ID_Estrato      Canon  Area_Construida  \
# 0           0 -70.450000  70.230000          4  1550000.0             68.0
# 1           1 -70.450000  70.230000          4  1850000.0             64.0
# 2           2 -75.567429   6.320024          4  1300000.0             64.0
#
#    Area_Privada  Antiguedad  Piso Habitaciones  Banios  Parqueadero  \
# 0          68.0         1.0     0            3       2            1
# 1           0.0         0.0     1            3       2            1
# 2          64.0         1.0     0            3       2            1
#
#    Administración Incluye_admin  \
# 0             0.0            NO
# 1             0.0            NO
# 2             0.0            NO
#
#                                          Descripcion   ciudad
# 0  apartamento de 68 metros aprox,  cuenta con pa...  LETICIA
# 1  la clasificación del estrato es potestativo de...  LETICIA
# 2  disponible para arrendar en el sector amazonia...  LETICIA

# %%
ofer =df.merge(city[['id_ciudad','ciudad']].drop_duplicates()
                ,left_on=['ID_Ciudad'],right_on=['id_ciudad'])

# %%
col_ofer = ['Longitud', 'Latitud',
       'ID_Estrato', 'Canon', 'Area_Construida', 'Area_Privada', 'Antiguedad',
       'Piso', 'Habitaciones', 'Banios', 'Parqueadero', 
       'Administración', 'Incluye_admin', 'Descripcion', 
       'ciudad']

# %%
ofer[col_ofer].to_csv("Ofertas_finales.csv",sep="|",ignore_index=True)

# %%
import folium

# %%
df['ciudad'].value_counts()
# Out:
# MEDELLIN              10405
# BOGOTA D.C.            9691
# BARRANQUILLA           3009
# CALI                   1334
# PEREIRA                 982
#                       ...
# MOCOA                     1
# SAN ZENON                 1
# POLO NUEVO                1
# QUIPILE                   1
# LA JAGUA DEL PILAR        1
# Name: ciudad, Length: 791, dtype: int64

# %%
import folium

# %%
center_lat = df.query("ciudad == 'BOGOTA D.C.'").Latitud.values[0]
center_lon = df.query("ciudad == 'BOGOTA D.C.'").Longitud.values[0]

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=20,
    tiles='OpenStreetMap',
    width='80%',
    ##Stamen Toner
)
m.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df = df.loc[df['ciudad']=='BOGOTA D.C.']

# %%
df['Indice'] =df.index

# %%
conta = 0
for i, row in df.iterrows():
    
    name = row.Indice
    lat = row.Latitud
    lon = row.Longitud
    # opened = row.codigo
    # HTML here in the pop up
    popup = '<b>Identificación= {}</br>'.format(name)

    folium.Marker([lat, lon], tooltip=name,popup=popup, icon=folium.Icon(color='green', icon='cloud'),
                  ).add_to(m)
    conta+=1
    if conta==100:
        break

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
